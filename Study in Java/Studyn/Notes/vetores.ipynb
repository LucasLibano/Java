# %% [markdown]
# - Array
#
# É uma estrutura de dados:
# Homogenea - dados.
# Ordenada (Elementos acessados por meio de posições)
# Alocada de uma vez só, em um bloco continuo de memoria.
#
# As vantagens são o acesso imediato aos elementos pela sua posição
#
# Desvantagens:
# Tamanho fixo
# Dificuldade para se realizar inserções e deleções.

# %%
#Sintaxe de vetor em java   

public static void main(String[] args) {

    Scanner sc = new Scanner(System.in);

    int n = sc.nexetDouble();
    double[] vect = new double[n];

    for (int =0; i<n; i++) {
        vect[i] = sc.nextDouble();
    }

# %% [markdown]
# vect.length é usado para obter o tamanho (quantidade de elementos) de um vetor (array).

# %%
for (int i = 0; i < vect.length; i++) {
    System.out.println(vect[i]);
}

# %% [markdown]
# laço “for-each” - ideal para percorrer todos os elementos de um array ou coleção sem precisar lidar com índices.

# %%
for (tipo elemento : arrayOuColecao) {
    // faça algo com "elemento"
}

# %%
int[] vect = {10, 20, 30, 40, 50};

for (int num : vect) {
    System.out.println(num);
}

#ou

String[] nomes = {"Lucas", "Ana", "Pedro"};

for (String nome : nomes) {
    System.out.println("Olá, " + nome + "!");
}

# %%
Sintaxe:

for (tipo apelido: colecao){
    comando 1
    comando 2
}
# Out:
#   Cell In[1], line 1
#     Sintaxe:
#             ^
# SyntaxError: invalid syntax
